# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Ford-GoBike-System-Data" data-toc-modified-id="Ford-GoBike-System-Data-1">Ford GoBike System Data</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#by-Joel-Minier-Matar" data-toc-modified-id="by-Joel-Minier-Matar-1.0.1">by Joel Minier-Matar</a></span></li></ul></li><li><span><a href="#Preliminary-Wrangling" data-toc-modified-id="Preliminary-Wrangling-1.1">Preliminary Wrangling</a></span><ul class="toc-item"><li><span><a href="#Quality-Issues-to-be-addressed" data-toc-modified-id="Quality-Issues-to-be-addressed-1.1.1">Quality Issues to be addressed</a></span></li><li><span><a href="#What-is-the-structure-of-your-dataset?" data-toc-modified-id="What-is-the-structure-of-your-dataset?-1.1.2">What is the structure of your dataset?</a></span></li><li><span><a href="#What-is/are-the-main-feature(s)-of-interest-in-your-dataset?" data-toc-modified-id="What-is/are-the-main-feature(s)-of-interest-in-your-dataset?-1.1.3">What is/are the main feature(s) of interest in your dataset?</a></span></li><li><span><a href="#What-features-in-the-dataset-do-you-think-will-help-support-your-investigation-into-your-feature(s)-of-interest?" data-toc-modified-id="What-features-in-the-dataset-do-you-think-will-help-support-your-investigation-into-your-feature(s)-of-interest?-1.1.4">What features in the dataset do you think will help support your investigation into your feature(s) of interest?</a></span></li></ul></li><li><span><a href="#Univariate-Exploration" data-toc-modified-id="Univariate-Exploration-1.2">Univariate Exploration</a></span><ul class="toc-item"><li><span><a href="#Discuss-the-distribution(s)-of-your-variable(s)-of-interest.-Were-there-any-unusual-points?-Did-you-need-to-perform-any-transformations?" data-toc-modified-id="Discuss-the-distribution(s)-of-your-variable(s)-of-interest.-Were-there-any-unusual-points?-Did-you-need-to-perform-any-transformations?-1.2.1">Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?</a></span></li><li><span><a href="#Of-the-features-you-investigated,-were-there-any-unusual-distributions?-Did-you-perform-any-operations-on-the-data-to-tidy,-adjust,-or-change-the-form-of-the-data?-If-so,-why-did-you-do-this?" data-toc-modified-id="Of-the-features-you-investigated,-were-there-any-unusual-distributions?-Did-you-perform-any-operations-on-the-data-to-tidy,-adjust,-or-change-the-form-of-the-data?-If-so,-why-did-you-do-this?-1.2.2">Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?</a></span></li></ul></li><li><span><a href="#Bivariate-Exploration" data-toc-modified-id="Bivariate-Exploration-1.3">Bivariate Exploration</a></span><ul class="toc-item"><li><span><a href="#Talk-about-some-of-the-relationships-you-observed-in-this-part-of-the-investigation.-How-did-the-feature(s)-of-interest-vary-with-other-features-in-the-dataset?" data-toc-modified-id="Talk-about-some-of-the-relationships-you-observed-in-this-part-of-the-investigation.-How-did-the-feature(s)-of-interest-vary-with-other-features-in-the-dataset?-1.3.1">Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?</a></span></li><li><span><a href="#Did-you-observe-any-interesting-relationships-between-the-other-features-(not-the-main-feature(s)-of-interest)?" data-toc-modified-id="Did-you-observe-any-interesting-relationships-between-the-other-features-(not-the-main-feature(s)-of-interest)?-1.3.2">Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?</a></span></li></ul></li><li><span><a href="#Multivariate-Exploration" data-toc-modified-id="Multivariate-Exploration-1.4">Multivariate Exploration</a></span><ul class="toc-item"><li><span><a href="#Talk-about-some-of-the-relationships-you-observed-in-this-part-of-the-investigation.-How-did-the-feature(s)-of-interest-vary-with-other-features-in-the-dataset?" data-toc-modified-id="Talk-about-some-of-the-relationships-you-observed-in-this-part-of-the-investigation.-How-did-the-feature(s)-of-interest-vary-with-other-features-in-the-dataset?-1.4.1">Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?</a></span></li><li><span><a href="#Did-you-observe-any-interesting-relationships-between-the-other-features-(not-the-main-feature(s)-of-interest)?" data-toc-modified-id="Did-you-observe-any-interesting-relationships-between-the-other-features-(not-the-main-feature(s)-of-interest)?-1.4.2">Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?</a></span></li></ul></li><li><span><a href="#Plots-for-presentation" data-toc-modified-id="Plots-for-presentation-1.5">Plots for presentation</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Ford GoBike System Data
# ###    by Joel Minier-Matar
#
# ## Preliminary Wrangling
#
# > The ford wheels dataset contains information about bicycle rides for subscribers and customer. The set has the duration in seconds for each ride as well as the starting and ending stations with their coordinates. It also has information about the method used to rent the bike (app or dipper) and about bike sharing rides.
#
# > For this study we will be looking at data for a full year from the beginning of April 2019 to the end of March 2020, over 2 million records will be analyzed. The original data files can be found at: https://www.lyft.com/bikes/bay-wheels/system-data

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import requests, zipfile, io
from math import sin, cos, sqrt, atan2, radians

# %matplotlib inline

# %% [markdown]
# Downloading dataset programmatically in case we need to add additional files in the future and storing the filenames in a list to load it into Pandas

# %%
#Data source: https://www.lyft.com/bikes/bay-wheels/system-data
data_to_download=['201904','201905','201906','201907','201908','201909','201910','201911','201912','202001','202002','202003']
for file_date in data_to_download:
    if int(file_date)<201905: #adjusting filenames to account for file name change
        name='fordgobike'
    else:
        name='baywheels'
    url='https://s3.amazonaws.com/baywheels-data/'+file_date+'-'+name+'-tripdata.csv.zip'
    data_file = requests.get(url)
    zip_data = zipfile.ZipFile(io.BytesIO(data_file.content))
    zip_data.extractall("data")
    print(url.split('/')[-1][:-4])#printing the filename to track the downloaded files
# Out:
# 201904-fordgobike-tripdata.csv
# 201905-baywheels-tripdata.csv
# 201906-baywheels-tripdata.csv
# 201907-baywheels-tripdata.csv
# 201908-baywheels-tripdata.csv
# 201909-baywheels-tripdata.csv
# 201910-baywheels-tripdata.csv
# 201911-baywheels-tripdata.csv
# 201912-baywheels-tripdata.csv
# 202001-baywheels-tripdata.csv
# 202002-baywheels-tripdata.csv
# 202003-baywheels-tripdata.csv

# %%
#creating filename list to load files into pandas
data_to_download=['201904','201905','201906','201907','201908','201909','201910','201911','201912','202001','202002','202003']
filenames=[]
for file_date in data_to_download:
    if int(file_date)<201905: #adjusting filenames to account for file name change
        name='fordgobike'
    else:
        name='baywheels'
    filenames.append(file_date+'-'+name+'-tripdata.csv')
filenames
# Out:
# ['201904-fordgobike-tripdata.csv',
#  '201905-baywheels-tripdata.csv',
#  '201906-baywheels-tripdata.csv',
#  '201907-baywheels-tripdata.csv',
#  '201908-baywheels-tripdata.csv',
#  '201909-baywheels-tripdata.csv',
#  '201910-baywheels-tripdata.csv',
#  '201911-baywheels-tripdata.csv',
#  '201912-baywheels-tripdata.csv',
#  '202001-baywheels-tripdata.csv',
#  '202002-baywheels-tripdata.csv',
#  '202003-baywheels-tripdata.csv']

# %%
#loading all the data files into a single dataframe
df=pd.DataFrame()
for name in filenames:    
    data=pd.read_csv("data/"+name)
    df=pd.concat([df,data])
    
df.info()
# Out:
# /Users/jmmk/opt/anaconda3/envs/Udacity/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/jmmk/opt/anaconda3/envs/Udacity/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/jmmk/opt/anaconda3/envs/Udacity/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2780197 entries, 0 to 176798
# Data columns (total 15 columns):
#  #   Column                   Dtype
# ...

# %% [markdown]
# The warnings above is related to different datatype on the `bike_share_for_all_trip` and `rental_access_method`columns since some dataset only have one of the two columns. Those variables have been added each to a separate column filling the missing values with NaN.

# %%
df.isnull().sum()
# Out:
# duration_sec                     0
# start_time                       0
# end_time                         0
# start_station_id            566370
# start_station_name          564536
# start_station_latitude           0
# start_station_longitude          0
# end_station_id              568018
# end_station_name            566192
# end_station_latitude             0
# end_station_longitude            0
# bike_id                          0
# user_type                        0
# bike_share_for_all_trip    1148266
# rental_access_method       2041501
# dtype: int64

# %%
plt.hist(df['duration_sec']);

# %%
df.describe()
# Out:
#        duration_sec  start_station_id  start_station_latitude  \
# count  2.780197e+06      2.213827e+06            2.780197e+06
# mean   8.166443e+02      1.544218e+02            3.775789e+01
# std    1.899538e+03      1.300140e+02            1.783507e-01
# min    6.000000e+01      3.000000e+00            0.000000e+00
# 25%    3.690000e+02      5.000000e+01            3.776710e+01
# 50%    5.880000e+02      1.090000e+02            3.777874e+01
# 75%    9.150000e+02      2.470000e+02            3.779423e+01
# max    9.121100e+05      5.210000e+02            4.551000e+01
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count             2.780197e+06    2.212179e+06          2.780197e+06
# mean             -1.223509e+02    1.494351e+02          3.775695e+01
# std               4.679862e-01    1.289548e+02          2.707893e-01
# min              -1.225143e+02    3.000000e+00          0.000000e+00
# ...

# %% [markdown]
# There are some very large durations that we need to remove.

# %%
df.duration_sec.quantile(0.99)
# Out:
# 4060.0

# %%
df[df['duration_sec']>=4060].count()
# Out:
# duration_sec               27803
# start_time                 27803
# end_time                   27803
# start_station_id           23092
# start_station_name         23108
# start_station_latitude     27803
# start_station_longitude    27803
# end_station_id             22568
# end_station_name           22587
# end_station_latitude       27803
# end_station_longitude      27803
# bike_id                    27803
# user_type                  27803
# bike_share_for_all_trip    16732
# rental_access_method        6356
# dtype: int64

# %% [markdown]
# The `bike_share_for_all_trip` and `rental_access_method` columns have some missing values to keep in mind while analyzing the data.

# %% [markdown]
# ### Quality Issues to be addressed
# - Remove entries with durations above the 95 percentile (1803 sec)
# - Convert `start time` and `end_time` to timestamp
# - Add start months and year
# - `bike_share_for_all_trip`, `rental_access_method`, and `user_type` will be converted to categorical data type

# %% [markdown]
# Making a copy of the database

# %%
df_clean=df.copy()

# %%
df_clean=df_clean[df_clean['duration_sec']<=4060]
df_clean.describe()
# Out:
#        duration_sec  start_station_id  start_station_latitude  \
# count  2.752401e+06      2.190740e+06            2.752401e+06
# mean   7.138244e+02      1.539936e+02            3.775783e+01
# std    5.182559e+02      1.295616e+02            1.788484e-01
# min    6.000000e+01      3.000000e+00            0.000000e+00
# 25%    3.670000e+02      5.000000e+01            3.776710e+01
# 50%    5.830000e+02      1.090000e+02            3.777874e+01
# 75%    9.010000e+02      2.460000e+02            3.779416e+01
# max    4.060000e+03      5.210000e+02            4.551000e+01
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count             2.752401e+06    2.189616e+06          2.752401e+06
# mean             -1.223507e+02    1.486301e+02          3.775768e+01
# std               4.692365e-01    1.282719e+02          2.069899e-01
# min              -1.225143e+02    3.000000e+00          0.000000e+00
# ...

# %%
df_clean.start_time=pd.to_datetime(df_clean.start_time)
df_clean.end_time=pd.to_datetime(df_clean.end_time)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2752401 entries, 4 to 176798
# Data columns (total 15 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   duration_sec             int64
#  1   start_time               datetime64[ns]
#  2   end_time                 datetime64[ns]
#  3   start_station_id         float64
#  4   start_station_name       object
#  5   start_station_latitude   float64
#  6   start_station_longitude  float64
#  7   end_station_id           float64
#  8   end_station_name         object
#  9   end_station_latitude     float64
#  10  end_station_longitude    float64
#  11  bike_id                  int64
#  12  user_type                object
#  13  bike_share_for_all_trip  object
#  14  rental_access_method     object
# dtypes: datetime64[ns](2), float64(6), int64(2), object(5)
# memory usage: 336.0+ MB

# %% [markdown]
# Adding columns with the month and year of the trip (named `period`), as well as the day of the trip (Monday, Tuesday, etc) and the hour. That will be used to assess few trends and patterns.

# %%
df_clean['hour']=df_clean['start_time'].dt.hour
df_clean['weekday']=df_clean['start_time'].dt.day_name()
df_clean['weekday']=df_clean['weekday'].astype('category')
df_clean.weekday.cat.reorder_categories(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'], ordered=True, inplace=True)
df_clean['period']=df_clean['start_time'].dt.month_name()+'-'+(pd.DatetimeIndex(df_clean['start_time']).year).astype(str)
#Removing data from April 2020, since we only have few days from April in the March datafile
df_clean=df_clean[df_clean['period']!='April-2020']
df_clean['period']=df_clean['period'].astype('category')
#Setting order for the period category
df_clean.period.cat.reorder_categories(['April-2019', 'May-2019', 'June-2019', 'July-2019', 'August-2019', 'September-2019', 'October-2019', 'November-2019', 'December-2019', 'January-2020', 'February-2020', 'March-2020'], ordered=True, inplace=True)
df_clean.head()
# Out:
#    duration_sec              start_time                end_time  \
# 4          1128 2019-04-30 23:59:04.739 2019-05-01 00:17:53.091
# 5          1388 2019-04-30 23:53:05.982 2019-05-01 00:16:14.313
# 6           920 2019-04-30 23:57:56.340 2019-05-01 00:13:16.454
# 7           725 2019-04-30 23:56:11.219 2019-05-01 00:08:16.915
# 8           488 2019-04-30 23:59:00.660 2019-05-01 00:07:08.975
#
#    start_station_id                                 start_station_name  \
# 4             124.0                              19th St at Florida St
# 5             243.0                        Bancroft Way at College Ave
# 6             202.0                            Washington St at 8th St
# 7              44.0  Civic Center/UN Plaza BART Station (Market St ...
# 8              21.0   Montgomery St BART Station (Market St at 2nd St)
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 4               37.760447              -122.410807             5.0
# ...

# %%
df_clean[df_clean['period']!='April-2020']
# Out:
#         duration_sec              start_time                end_time  \
# 4               1128 2019-04-30 23:59:04.739 2019-05-01 00:17:53.091
# 5               1388 2019-04-30 23:53:05.982 2019-05-01 00:16:14.313
# 6                920 2019-04-30 23:57:56.340 2019-05-01 00:13:16.454
# 7                725 2019-04-30 23:56:11.219 2019-05-01 00:08:16.915
# 8                488 2019-04-30 23:59:00.660 2019-05-01 00:07:08.975
# ...              ...                     ...                     ...
# 176789           192 2020-03-23 16:17:02.000 2020-03-23 16:20:15.000
# 176790            63 2020-03-23 11:31:18.000 2020-03-23 11:32:21.000
# 176791           310 2020-03-23 16:11:17.000 2020-03-23 16:16:27.000
# 176795            78 2020-03-18 17:10:42.000 2020-03-18 17:12:01.000
# 176798           333 2020-03-23 16:39:57.000 2020-03-23 16:45:30.000
#
#         start_station_id                                 start_station_name  \
# ...

# %% [markdown]
# Then we will adjust some of the datatypes.

# %%
df_clean.user_type=df_clean.user_type.astype('category')
df_clean.bike_share_for_all_trip=df_clean.bike_share_for_all_trip.astype('category')
df_clean.rental_access_method=df_clean.rental_access_method.astype('category')
#Setting order for the user_type categories
df_clean.user_type.cat.reorder_categories(['Subscriber','Customer'], ordered=True, inplace=True)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2750723 entries, 4 to 176798
# Data columns (total 18 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   duration_sec             int64
#  1   start_time               datetime64[ns]
#  2   end_time                 datetime64[ns]
#  3   start_station_id         float64
#  4   start_station_name       object
#  5   start_station_latitude   float64
#  6   start_station_longitude  float64
#  7   end_station_id           float64
#  8   end_station_name         object
#  9   end_station_latitude     float64
#  10  end_station_longitude    float64
#  11  bike_id                  int64
#  12  user_type                category
#  13  bike_share_for_all_trip  category
#  14  rental_access_method     category
#  15  hour                     int64
#  16  weekday                  category
#  17  period                   category
# dtypes: category(5), datetime64[ns](2), float64(6), int64(3), object(2)
# ...

# %% [markdown]
# ### What is the structure of your dataset?
#
# > The data set consist of one quantitative data (duration in seconds) and several qualitative data fields: starting and ending station IDs and Names as well as the method of renting the bike and the type of user (subscriber or customer).
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# > The main feature of interest are the duration of each ride as well as the type of customer. That will tell which group is the main user of the bike system. Also the method of renting the bike and the usage based on the day of the week and hour of the day.
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# > Trip duration, trip day (weekday or weekend), type of user and start/end trip stations.

# %% [markdown]
# ## Univariate Exploration
#
# > Now that we adjusted our dataset, we will look for some trends.

# %%
bin_edges = np.arange(0, df_clean['duration_sec'].max()+100, 100)
plt.hist(df_clean['duration_sec'], bins = bin_edges);

# %% [markdown]
# The histogram for the time duration of each ride shows that an average duration of around 700 seconds (11-12 min) and it shows an exponential decline towards higher values.

# %%
sns.countplot(data=df_clean,x='user_type');

# %% [markdown]
# Let's check the same distribution transforming the Y-axis to percentage

# %%
typepercent=df_clean.user_type.value_counts(normalize=True).apply(lambda x: x*100) #Normalizinmg the counts and transforming to percentage
print (typepercent)
fig, ax = plt.subplots(1,1)
sns.barplot(x=typepercent.index,y=typepercent)
plt.ylim(0,100)
plt.ylabel('User_type Percentage')
rects=ax.patches
for rect in rects:
    h = rect.get_height()
    ax.text(rect.get_x()+rect.get_width()/2., h+2,'{:0.0f}%'.format(h), ha='center', va='bottom');
# Out:
# Subscriber    72.930281
# Customer      27.069719
# Name: user_type, dtype: float64

# %% [markdown]
# From the bike system users, over the year in consideration, 73% of the users are subscribers while 27% are customer

# %%
sns.countplot(data=df_clean,x='bike_share_for_all_trip');

# %% [markdown]
# Let's check the same distribution by normalizing the counts

# %%
typepercent=df_clean.bike_share_for_all_trip.value_counts(normalize=True)
print (typepercent)
sns.barplot(x=typepercent.index,y=typepercent);
# Out:
# No     0.925025
# Yes    0.074975
# Name: bike_share_for_all_trip, dtype: float64

# %% [markdown]
# Most of the rides (~93%) are not share rides. This that is only based on the availabe since few months do not have bike share data

# %%
sns.countplot(data=df_clean,x='rental_access_method');

# %% [markdown]
# Let's check the same distribution by normalizing the counts

# %%
typepercent=df_clean.rental_access_method.value_counts(normalize=True)
print (typepercent)
sns.barplot(x=typepercent.index,y=typepercent);
# Out:
# app        0.918191
# clipper    0.081809
# Name: rental_access_method, dtype: float64

# %% [markdown]
# 92% of the rides are rented from the app. This data is also based on the available data since few months do not have rental access data.

# %%
bin_data=range(0,25,1)
plt.hist(df_clean.start_time.dt.hour, bins=bin_data)
plt.xlabel('hour of the day')
plt.title("Overall");

# %% [markdown]
# The histogram based on the hour of the day shows a bimodal distribution. The peak times for bike rides are in the morning between 7-10 am and in the evening between 4-7 pm. Let's split the same distribution based on weekdays and weekend.

# %%
bin_data=range(0,25,1)
plt.hist(df_clean.query('weekday!="Sunday" and weekday!="Saturday"')['hour'], bins=bin_data)
plt.xlabel('hour of the day')
plt.title("Weekdays");

# %% [markdown]
# Weekdays trends are very similar to the overall trend showed above

# %%
bin_data=range(0,25,1)
plt.hist(df_clean.query('weekday=="Sunday" or weekday=="Saturday"')['hour'], bins=bin_data)
plt.xlabel('hour of the day')
plt.title("Weekend");

# %% [markdown]
# Weekend trends are different. It shows an unimodal distribution with peak rides in the early afternoon (2-3 pm)

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# > The duration of each trip had some very large numbers. To be able to visualize the data correctly, I removed points above the 99 percentile.
#
# > I also did some transformations from counts to percentage to determine the percentage distribution (normalized values) for some categories.
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# >  I noticed a bimodal distribution for the number of trips depending on the hour of the day. We will explore this further to see if other factors affect the number of trips
#
# > Regarding wrangling efforts, I converted the time data into numpy datetime datatype to be able to extract the month and the year of each trip for grouping purposes. Additionally, I extracted the hour of the trip (based on start time) and the weekday. I also change some datatypes to `ordered category` to be able to plot the data correctly.

# %% [markdown]
# ## Bivariate Exploration
#
# > In this section, we will investigate relationships between pairs of variables

# %%
base_color = sns.color_palette()[0]
sns.boxplot(data = df_clean, x = 'user_type', y = 'duration_sec', color = base_color);

# %% [markdown]
# The box plot showed that the subscribers on average had slightly lower duration time compared to customers, as well as lower quartiles

# %%
base_color = sns.color_palette()[0]
sns.violinplot(data = df_clean, y = 'user_type', x = 'duration_sec', color = base_color);

# %% [markdown]
# The violin plot is similar to the box plot, and it showed that the time distribution is unimodal for both category. In this case, the box plot seems to be more explanatory.

# %%
base_color = sns.color_palette()[0]
sns.boxplot(data = df_clean, x = 'rental_access_method', y = 'duration_sec', color = base_color);

# %% [markdown]
# The rides for rental using the app have a slightly longer average duration compared to those from the clipper. The box plot also showed that data above 2000 sec are above 1.5IQR (inter quartile range)

# %%
base_color = sns.color_palette()[0]
sns.violinplot(data = df_clean, y = 'rental_access_method', x = 'duration_sec', color = base_color);

# %% [markdown]
# The violin plot is similar to the box plot, and it showed that the time distribution is unimodal for both rental category.  In this case, the box plot seems to be more explanatory

# %%
time_vs_day=df_clean.groupby(['weekday']).mean()['duration_sec']
print (time_vs_day)
plt.ylabel('Trip duration in seconds')
time_vs_day.plot.bar();
# Out:
# weekday
# Monday       686.558851
# Tuesday      677.838786
# Wednesday    682.889930
# Thursday     683.614887
# Friday       703.908686
# Saturday     833.599928
# Sunday       825.678880
# Name: duration_sec, dtype: float64

# %% [markdown]
# There is a slightly increase on the average duration time on weekends compared to weekdays

# %%
(time_vs_day/time_vs_day.sum()).apply(lambda x: x*100).plot.bar()
plt.ylabel('Trip duration - Percentage based on average');

# %% [markdown]
# The increase is approximately 2 to 3%

# %% [markdown]
# Now let's check with stations are more popular and what are the peak time for those stations

# %%
stations=df_clean['start_station_name'].value_counts().rename_axis('start_station_name').reset_index(name='counts')
station_10_start=stations.head(10)
station_10_start
# Out:
#                                   start_station_name  counts
# 0                               Market St at 10th St   39423
# 1                                 Berry St at 4th St   39282
# 2     San Francisco Caltrain (Townsend St at 4th St)   38535
# 3  San Francisco Ferry Building (Harry Bridges Pl...   32796
# 4   Montgomery St BART Station (Market St at 2nd St)   30360
# 5       Powell St BART Station (Market St at 4th St)   29027
# 6                              Howard St at Beale St   28688
# 7       Powell St BART Station (Market St at 5th St)   26523
# 8                            Steuart St at Market St   24694
# 9  San Francisco Caltrain Station 2  (Townsend St...   24392

# %%
sns.barplot(data=station_10_start,y='start_station_name',x='counts', order=station_10_start.start_station_name);

# %% [markdown]
# Market St, Berry St and San Francisco Caltrain stations are the most popular stations to start a ride. Let's check the time distribution for the first station: Market st.

# %%
bin_data=range(0,25,1)
plt.hist(df_clean[df_clean.start_station_name==station_10_start.start_station_name[0]]['start_time'].dt.hour, bins=bin_data)
plt.title(station_10_start.start_station_name[0]);

# %% [markdown]
# The plot above showed a bimodal distribution for the trips from the Market st station are from 8-10 am and from 4 to 7 pm.

# %%
stations_end=df_clean['end_station_name'].value_counts().rename_axis('end_station_name').reset_index(name='counts')
station_10_end=stations_end.head(10)
station_10_end
# Out:
#                                     end_station_name  counts
# 0     San Francisco Caltrain (Townsend St at 4th St)   54847
# 1   Montgomery St BART Station (Market St at 2nd St)   43455
# 2  San Francisco Ferry Building (Harry Bridges Pl...   42308
# 3                                 Berry St at 4th St   39672
# 4                               Market St at 10th St   38651
# 5  San Francisco Caltrain Station 2  (Townsend St...   34840
# 6       Powell St BART Station (Market St at 4th St)   32865
# 7       Powell St BART Station (Market St at 5th St)   27659
# 8                              Howard St at Beale St   27457
# 9                      The Embarcadero at Sansome St   26520

# %%
sns.barplot(data=station_10_end,y='end_station_name',x='counts', order=station_10_end.end_station_name);

# %% [markdown]
# San Francisco Caltrain stations seems to be the most popular station to end a ride.

# %% [markdown]
# Let's check the time distribution for both Market st at 10 st and San Francisco Caltrain stationds.

# %%
plt.figure(figsize = [15, 5])
base_color = sns.color_palette()[0]
bin_data=range(0,25,1)
# left plot
plt.subplot(1, 2, 1)
plt.hist(df_clean[df_clean.start_station_name==station_10_start.start_station_name[0]]['start_time'].dt.hour, bins=bin_data);
plt.title('Starting station: ' + station_10_start.start_station_name[0])
plt.xlabel('Hour of the day - Start time')
plt.ylabel ('Number of trips')
plt.ylim(0,6000)
# right plot
plt.subplot(1, 2, 2)
plt.hist(df_clean[df_clean.end_station_name==station_10_end.end_station_name[4]]['end_time'].dt.hour, bins=bin_data)
plt.title('End station: '+station_10_end.end_station_name[4])
plt.xlabel('Hour of the day - End time')
plt.ylabel ('Number of trips')
plt.ylim(0,6000);

# %% [markdown]
# The plots above showed the number of rides starting (left) and ending (right) at the Market St at 10th St station at different time of the day.

# %%
plt.figure(figsize = [15, 5])
base_color = sns.color_palette()[0]
bin_data=range(0,25,1)
# left plot
plt.subplot(1, 2, 1)
plt.hist(df_clean[df_clean.start_station_name==station_10_start.start_station_name[2]]['start_time'].dt.hour, bins=bin_data);
plt.title('Starting station: ' + station_10_start.start_station_name[2])
plt.xlabel('Hour of the day - Start time')
plt.ylabel ('Number of trips')
plt.ylim(0,14000)
# right plot
plt.subplot(1, 2, 2)
plt.hist(df_clean[df_clean.end_station_name==station_10_end.end_station_name[0]]['end_time'].dt.hour, bins=bin_data)
plt.title('End station: '+station_10_end.end_station_name[0])
plt.xlabel('Hour of the day - End time')
plt.ylabel ('Number of trips')
plt.ylim(0,14000);

# %% [markdown]
# The plots above showed the number of rides starting (left) and ending (right) at the San Francisco Caltrain station at different time of the day. The biggest peak is an ending station in the evenings

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# > We observed that the time distribution varies depending on which station we are looking at; and that could give us an indication when to expect higher demands in different locations.
#
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > We noticed a difference in the average trip duration for the different user type: customer and subscriber. Also, there seems to be an increase in the average duration (approximately 3%) for rides taking on weekends compared to weekdays.

# %% [markdown]
# ## Multivariate Exploration
#
# > Now we will explore additional correlation between variables, like the monthly and hourly trends.

# %%
g = sns.FacetGrid(data = df_clean, col = 'period', col_wrap=4)
g.map(sns.countplot,'user_type', order=['Subscriber','Customer'],palette=sns.color_palette());

# %% [markdown]
# The number of users per month showed that subscribers are dominant. it is interesting that the number of trips in April 2020 is the lowest possible due to the COVID-19 lock-down restrictions. The highest number of trips was in February, possible due to the end of winter.

# %%
bin_edges = np.arange(0, 4000+100, 100)
g = sns.FacetGrid(data =df_clean, col = 'period', col_wrap=4)
g.map(plt.hist,'duration_sec',bins=bin_edges);

# %% [markdown]
# The histogram facegrid also showed the same trend for April 2020

# %% [markdown]
# Now let's see the trends based on the day of the week.

# %%
bin_edges = np.arange(0, 4000+100, 100)
g = sns.FacetGrid(data =df_clean, col= 'weekday')
g.map(plt.hist,'duration_sec',bins=bin_edges);

# %% [markdown]
# Based on the plot above, the bike system is used more during weekdays than weekends.

# %%
g = sns.FacetGrid(data = df_clean, col = 'weekday')
g.map(sns.countplot,'user_type', order=['Subscriber','Customer'], palette=sns.color_palette());

# %% [markdown]
# The proportions of subscriber compared to customer is higher in weekdays than weekends.

# %% [markdown]
# Let's check the hourly trends per month overall and for the market st station.

# %%
bin_data=range(0,25,1)
g = sns.FacetGrid(data =df_clean, col = 'period', col_wrap=4)
g.map(plt.hist,'hour',bins=bin_data);
print('Overall hourly trend')
# Out:
# Overall hourly trend

# %%
bin_data=range(0,25,1)
g = sns.FacetGrid(data =df_clean[df_clean.start_station_name==station_10_start.start_station_name[0]], col = 'period', col_wrap=4)
g.map(plt.hist,'hour',bins=bin_data);
print('Hourly trend for {} station'.format(station_10_start.start_station_name[0]))
# Out:
# Hourly trend for Market St at 10th St station

# %%
bin_data=range(0,25,1)
g = sns.FacetGrid(data =df_clean[df_clean.start_station_name==station_10_start.start_station_name[0]].query('weekday=="Sunday" or weekday=="Saturday"'), col = 'period', col_wrap=4)
g.map(plt.hist,'hour',bins=bin_data);
print('Hourly trend for {} station on Weekends'.format(station_10_start.start_station_name[0]))
# Out:
# Hourly trend for Market St at 10th St station on Weekends

# %%
bin_data=range(0,25,1)
g = sns.FacetGrid(data =df_clean[df_clean.start_station_name==station_10_start.start_station_name[0]].query('weekday!="Sunday" and weekday!="Saturday"'), col = 'period', col_wrap=4)
g.map(plt.hist,'hour',bins=bin_data);
print('Hourly trend for {} station on weekdays'.format(station_10_start.start_station_name[0]))
# Out:
# Hourly trend for Market St at 10th St station on weekdays

# %% [markdown]
# The weekdays and weekend trends for Market st at 10th st station are similar for each month analyzed. Based on this we could predict the needs of bikes at given time of the day.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# > The monthly trends revealed a decrease on rides in December, possible due to the Christmas holidays; and in March 2020 probably due to the COVID-19 lock-down. The data also showed an increase in rides on February 2020; possible due to the end of winter and better weather for riding.
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > It was interesting to see the different patterns between the weekdays and weekend rides. During weekdays, most of the rides are in peak hours (7-10 am and 4-7 pm), while in weekends the rides are mainly in the afternoon. I also observed that weekdays rides are mainly done by subscriber while on weekend the proportion of subscribers and customers are close to each other.

# %% [markdown]
# ## Plots for presentation

# %%
typepercent=df_clean.user_type.value_counts(normalize=True).apply(lambda x: x*100) #Normalizinmg the counts and transforming to percentage
fig, ax = plt.subplots(1,1)
sns.barplot(x=typepercent.index,y=typepercent)
plt.ylim(0,100)
plt.ylabel('User_type Percentage')
plt.title('Percentage of users based on type')
rects=ax.patches
for rect in rects:
    h = rect.get_height()
    ax.text(rect.get_x()+rect.get_width()/2., h+2,'{:0.0f}%'.format(h), ha='center', va='bottom');

# %%
bin_edges = np.arange(0, df_clean['duration_sec'].max()+100, 100)
plt.hist(df_clean['duration_sec'], bins = bin_edges)
plt.xlabel('Trip duration, sec')
plt.ylabel('Number of trips, counts')
plt.title('Trip duration histogram');

# %%
plt.figure(figsize = [16,4])
base_color = sns.color_palette()[0]
bin_data=range(0,25,1)
plt.subplot(1, 3, 1)
plt.hist(df_clean.start_time.dt.hour, bins=bin_data)
plt.xlabel('Hour of the day - Start time, h')
plt.title("Overall number of trips")
plt.ylabel('Number of trips, counts')
plt.ylim(0,350000);
plt.subplot(1, 3, 2)
plt.hist(df_clean.query('weekday!="Sunday" and weekday!="Saturday"')['hour'], bins=bin_data)
plt.xlabel('Hour of the day - Start time, h')
plt.title("Weekdays number of trips")
plt.ylim(0,350000);
plt.subplot(1, 3, 3)
plt.hist(df_clean.query('weekday=="Sunday" or weekday=="Saturday"')['hour'], bins=bin_data)
plt.xlabel('Hour of the day - Start time, h')
plt.title("Weekend number of trips")
plt.ylim(0,350000);

# %%
stations=df_clean['start_station_name'].value_counts().rename_axis('start_station_name').reset_index(name='counts')
station_10_start=stations.head(10)
stations_end=df_clean['end_station_name'].value_counts().rename_axis('end_station_name').reset_index(name='counts')
station_10_end=stations_end.head(10)

# %%
sns.barplot(data=station_10_start,y='start_station_name',x='counts', order=station_10_start.start_station_name)
plt.xlabel('Number of trips')
plt.title("Number of trips for the top 10 stations ")
plt.ylabel('Stations');

# %%
plt.figure(figsize = [15, 5])
base_color = sns.color_palette()[0]
bin_data=range(0,25,1)
# left plot
plt.subplot(1, 2, 1)
plt.hist(df_clean[df_clean.start_station_name==station_10_start.start_station_name[0]]['start_time'].dt.hour, bins=bin_data);
plt.title('Starting station: ' + station_10_start.start_station_name[0])
plt.xlabel('Hour of the day - Start time, h')
plt.ylabel ('Number of trips')
plt.ylim(0,6000)
# right plot
plt.subplot(1, 2, 2)
plt.hist(df_clean[df_clean.end_station_name==station_10_end.end_station_name[4]]['end_time'].dt.hour, bins=bin_data)
plt.title('End station: '+station_10_end.end_station_name[4])
plt.xlabel('Hour of the day - End time, h')
plt.ylabel ('Number of trips')
plt.ylim(0,6000);

# %%
bin_data=range(0,25,1)
g = sns.FacetGrid(data =df_clean, col = 'period', col_wrap=4)
g.map(plt.hist,'hour',bins=bin_data)
g.axes[8].set_xlabel('Hour of the day - Start time, h')
g.axes[9].set_xlabel('Hour of the day - Start time, h')
g.axes[10].set_xlabel('Hour of the day - Start time, h')
g.axes[11].set_xlabel('Hour of the day - Start time, h')
g.axes[0].set_ylabel('Number of trips, counts')
g.axes[4].set_ylabel('Number of trips, counts')
g.axes[8].set_ylabel('Number of trips, counts');

# %%
g = sns.FacetGrid(data = df_clean, col = 'weekday',col_wrap=4)
g.map(sns.countplot,'user_type', order=['Subscriber','Customer'],palette=sns.color_palette())
g.axes[3].set_xlabel('Type of user')
g.axes[4].set_xlabel('Type of user')
g.axes[5].set_xlabel('Type of user')
g.axes[6].set_xlabel('Type of user')
g.axes[0].set_ylabel('Number of trips, counts')
g.axes[4].set_ylabel('Number of trips, counts');
